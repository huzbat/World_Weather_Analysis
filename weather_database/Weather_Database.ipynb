# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from scipy import stats
from datetime import datetime
import time

import requests
# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 616

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=735e952ef36cc3a9ab375a710a348b15

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description = city_weather["weather"][0]["description"]

        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,                          
                          "Current Description": city_weather_description,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nikolskoye
# Processing Record 2 of Set 1 | fortuna
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | cherskiy
# Processing Record 6 of Set 1 | college
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | bluff
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | aybak
# City not found. Skipping...
# Processing Record 11 of Set 1 | castro
# Processing Record 12 of Set 1 | banswara
# Processing Record 13 of Set 1 | dawlatabad
# Processing Record 14 of Set 1 | tezu
# Processing Record 15 of Set 1 | lingao
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | ponferrada
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | port-gentil
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | airai
# Processing Record 22 of Set 1 | avarua
# Processing Record 23 of Set 1 | kutum
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | samarai
# Processing Record 26 of Set 1 | baiyin
# Processing Record 27 of Set 1 | saryg-sep
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | adrar
# Processing Record 30 of Set 1 | khatanga
# Processing Record 31 of Set 1 | tabou
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | chokurdakh
# Processing Record 34 of Set 1 | narsaq
# Processing Record 35 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 36 of Set 1 | san patricio
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | gisborne
# Processing Record 41 of Set 1 | alta floresta
# Processing Record 42 of Set 1 | tak
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | broome
# Processing Record 46 of Set 1 | kailua
# Processing Record 47 of Set 1 | baruun-urt
# Processing Record 48 of Set 1 | grindavik
# Processing Record 49 of Set 1 | atuona
# Processing Record 50 of Set 1 | asheboro
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | cidreira
# Processing Record 3 of Set 2 | yeghegnavan
# Processing Record 4 of Set 2 | gigmoto
# Processing Record 5 of Set 2 | kulhudhuffushi
# Processing Record 6 of Set 2 | inuvik
# Processing Record 7 of Set 2 | sur
# Processing Record 8 of Set 2 | east london
# Processing Record 9 of Set 2 | butaritari
# Processing Record 10 of Set 2 | busselton
# Processing Record 11 of Set 2 | villazon
# Processing Record 12 of Set 2 | domoni
# Processing Record 13 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 14 of Set 2 | hobart
# Processing Record 15 of Set 2 | korla
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | komsomolskoye
# Processing Record 18 of Set 2 | saint-augustin
# Processing Record 19 of Set 2 | tazovskiy
# Processing Record 20 of Set 2 | den helder
# Processing Record 21 of Set 2 | kafanchan
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 24 of Set 2 | akyab
# Processing Record 25 of Set 2 | constitucion
# Processing Record 26 of Set 2 | lawrenceburg
# Processing Record 27 of Set 2 | sao joao da barra
# Processing Record 28 of Set 2 | zyryanka
# Processing Record 29 of Set 2 | namtsy
# Processing Record 30 of Set 2 | ventspils
# Processing Record 31 of Set 2 | kolobrzeg
# Processing Record 32 of Set 2 | bredasdorp
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | bontang
# Processing Record 35 of Set 2 | hasaki
# Processing Record 36 of Set 2 | honiara
# Processing Record 37 of Set 2 | iracoubo
# Processing Record 38 of Set 2 | surt
# Processing Record 39 of Set 2 | cap malheureux
# Processing Record 40 of Set 2 | barao de melgaco
# Processing Record 41 of Set 2 | klyuchi
# Processing Record 42 of Set 2 | lompoc
# Processing Record 43 of Set 2 | nanortalik
# Processing Record 44 of Set 2 | arcachon
# Processing Record 45 of Set 2 | turkmenabat
# Processing Record 46 of Set 2 | houston
# Processing Record 47 of Set 2 | tolaga bay
# Processing Record 48 of Set 2 | toamasina
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | kyzyl-suu
# Processing Record 1 of Set 3 | sochaczew
# Processing Record 2 of Set 3 | mao
# Processing Record 3 of Set 3 | daru
# Processing Record 4 of Set 3 | tabuk
# Processing Record 5 of Set 3 | nyagan
# Processing Record 6 of Set 3 | athabasca
# Processing Record 7 of Set 3 | comodoro rivadavia
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | rio gallegos
# Processing Record 10 of Set 3 | acajutla
# Processing Record 11 of Set 3 | pisco
# Processing Record 12 of Set 3 | diu
# Processing Record 13 of Set 3 | marolambo
# Processing Record 14 of Set 3 | longyearbyen
# Processing Record 15 of Set 3 | napa
# Processing Record 16 of Set 3 | bengkulu
# Processing Record 17 of Set 3 | warkworth
# Processing Record 18 of Set 3 | hilo
# Processing Record 19 of Set 3 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 3 | provideniya
# Processing Record 21 of Set 3 | fairbanks
# Processing Record 22 of Set 3 | primero de enero
# Processing Record 23 of Set 3 | talnakh
# Processing Record 24 of Set 3 | mogadishu
# Processing Record 25 of Set 3 | tiksi
# Processing Record 26 of Set 3 | cabo san lucas
# Processing Record 27 of Set 3 | arman
# Processing Record 28 of Set 3 | manicore
# Processing Record 29 of Set 3 | campana
# Processing Record 30 of Set 3 | hihifo
# City not found. Skipping...
# Processing Record 31 of Set 3 | erenhot
# Processing Record 32 of Set 3 | pahrump
# Processing Record 33 of Set 3 | stettler
# Processing Record 34 of Set 3 | hofn
# Processing Record 35 of Set 3 | tahta
# Processing Record 36 of Set 3 | vardo
# Processing Record 37 of Set 3 | new norfolk
# Processing Record 38 of Set 3 | saskylakh
# Processing Record 39 of Set 3 | mendahara
# City not found. Skipping...
# Processing Record 40 of Set 3 | chicama
# Processing Record 41 of Set 3 | letlhakane
# Processing Record 42 of Set 3 | mikropolis
# Processing Record 43 of Set 3 | bilma
# Processing Record 44 of Set 3 | dangriga
# Processing Record 45 of Set 3 | victoria
# Processing Record 46 of Set 3 | jining
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 49 of Set 3 | tsiroanomandidy
# Processing Record 50 of Set 3 | atbasar
# Processing Record 1 of Set 4 | colares
# Processing Record 2 of Set 4 | touros
# Processing Record 3 of Set 4 | barrow
# Processing Record 4 of Set 4 | lebedinyy
# Processing Record 5 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 8 of Set 4 | san quintin
# Processing Record 9 of Set 4 | ponta delgada
# Processing Record 10 of Set 4 | san cristobal
# Processing Record 11 of Set 4 | edson
# Processing Record 12 of Set 4 | zhigansk
# Processing Record 13 of Set 4 | kahului
# Processing Record 14 of Set 4 | havoysund
# Processing Record 15 of Set 4 | ames
# Processing Record 16 of Set 4 | rocha
# Processing Record 17 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 18 of Set 4 | luderitz
# Processing Record 19 of Set 4 | puerto ayora
# Processing Record 20 of Set 4 | huarmey
# Processing Record 21 of Set 4 | turukhansk
# Processing Record 22 of Set 4 | sao jose da coroa grande
# Processing Record 23 of Set 4 | gazojak
# Processing Record 24 of Set 4 | aklera
# Processing Record 25 of Set 4 | new castle
# Processing Record 26 of Set 4 | pozo colorado
# Processing Record 27 of Set 4 | ahipara
# Processing Record 28 of Set 4 | tubuala
# Processing Record 29 of Set 4 | faanui
# Processing Record 30 of Set 4 | ribeira grande
# Processing Record 31 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 4 | nabire
# Processing Record 33 of Set 4 | la asuncion
# Processing Record 34 of Set 4 | zharkent
# Processing Record 35 of Set 4 | skalistyy
# City not found. Skipping...
# Processing Record 36 of Set 4 | ilo
# Processing Record 37 of Set 4 | kampong thum
# Processing Record 38 of Set 4 | nemuro
# Processing Record 39 of Set 4 | mayo
# Processing Record 40 of Set 4 | ballina
# Processing Record 41 of Set 4 | meiktila
# Processing Record 42 of Set 4 | dikson
# Processing Record 43 of Set 4 | wildwood
# Processing Record 44 of Set 4 | wa
# City not found. Skipping...
# Processing Record 45 of Set 4 | dingle
# Processing Record 46 of Set 4 | nome
# Processing Record 47 of Set 4 | carauari
# Processing Record 48 of Set 4 | portland
# Processing Record 49 of Set 4 | bibiani
# Processing Record 50 of Set 4 | georgetown
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | kautokeino
# Processing Record 3 of Set 5 | tacuarembo
# Processing Record 4 of Set 5 | upernavik
# Processing Record 5 of Set 5 | tuktoyaktuk
# Processing Record 6 of Set 5 | saint-pierre
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | namibe
# Processing Record 9 of Set 5 | englehart
# Processing Record 10 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 11 of Set 5 | belyy
# Processing Record 12 of Set 5 | acapulco
# Processing Record 13 of Set 5 | kolochava
# Processing Record 14 of Set 5 | umm lajj
# Processing Record 15 of Set 5 | bathsheba
# Processing Record 16 of Set 5 | avera
# Processing Record 17 of Set 5 | gat
# Processing Record 18 of Set 5 | alberton
# Processing Record 19 of Set 5 | aklavik
# Processing Record 20 of Set 5 | thoen
# Processing Record 21 of Set 5 | melilla
# Processing Record 22 of Set 5 | esso
# Processing Record 23 of Set 5 | meulaboh
# Processing Record 24 of Set 5 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 25 of Set 5 | yar-sale
# Processing Record 26 of Set 5 | caravelas
# Processing Record 27 of Set 5 | mahebourg
# Processing Record 28 of Set 5 | banmo
# City not found. Skipping...
# Processing Record 29 of Set 5 | saint anthony
# Processing Record 30 of Set 5 | guerrero negro
# Processing Record 31 of Set 5 | zhanaozen
# Processing Record 32 of Set 5 | sergeyevka
# Processing Record 33 of Set 5 | belmonte
# Processing Record 34 of Set 5 | moose factory
# Processing Record 35 of Set 5 | do gonbadan
# Processing Record 36 of Set 5 | mocuba
# Processing Record 37 of Set 5 | lorengau
# Processing Record 38 of Set 5 | trincomalee
# Processing Record 39 of Set 5 | ambon
# Processing Record 40 of Set 5 | northam
# Processing Record 41 of Set 5 | zhurivka
# Processing Record 42 of Set 5 | souillac
# Processing Record 43 of Set 5 | jamestown
# Processing Record 44 of Set 5 | muros
# Processing Record 45 of Set 5 | komsomolskiy
# Processing Record 46 of Set 5 | port said
# Processing Record 47 of Set 5 | klaksvik
# Processing Record 48 of Set 5 | yasothon
# Processing Record 49 of Set 5 | hervey bay
# Processing Record 50 of Set 5 | ulaanbaatar
# Processing Record 1 of Set 6 | lofthus
# Processing Record 2 of Set 6 | baniachang
# Processing Record 3 of Set 6 | kodiak
# Processing Record 4 of Set 6 | cayenne
# Processing Record 5 of Set 6 | jalu
# Processing Record 6 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 7 of Set 6 | bucerias
# Processing Record 8 of Set 6 | carbondale
# Processing Record 9 of Set 6 | monaghan
# Processing Record 10 of Set 6 | kavieng
# Processing Record 11 of Set 6 | katsuura
# Processing Record 12 of Set 6 | iqaluit
# Processing Record 13 of Set 6 | torbay
# Processing Record 14 of Set 6 | hambantota
# Processing Record 15 of Set 6 | nuuk
# Processing Record 16 of Set 6 | kaeo
# Processing Record 17 of Set 6 | cabedelo
# Processing Record 18 of Set 6 | spanish town
# Processing Record 19 of Set 6 | kenora
# Processing Record 20 of Set 6 | enshi
# Processing Record 21 of Set 6 | taoudenni
# Processing Record 22 of Set 6 | ostrovnoy
# Processing Record 23 of Set 6 | kokkola
# Processing Record 24 of Set 6 | bryan
# Processing Record 25 of Set 6 | sitka
# Processing Record 26 of Set 6 | pasni
# Processing Record 27 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 28 of Set 6 | augusto correa
# Processing Record 29 of Set 6 | griffith
# Processing Record 30 of Set 6 | chhatapur
# Processing Record 31 of Set 6 | dawei
# Processing Record 32 of Set 6 | pauini
# Processing Record 33 of Set 6 | mexticacan
# Processing Record 34 of Set 6 | namatanai
# Processing Record 35 of Set 6 | isabela
# Processing Record 36 of Set 6 | port lincoln
# Processing Record 37 of Set 6 | tevriz
# Processing Record 38 of Set 6 | punta alta
# Processing Record 39 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 6 | diamantino
# Processing Record 42 of Set 6 | chuy
# Processing Record 43 of Set 6 | arraial do cabo
# Processing Record 44 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 6 | leningradskiy
# Processing Record 46 of Set 6 | riosucio
# Processing Record 47 of Set 6 | pimentel
# Processing Record 48 of Set 6 | san pancrazio salentino
# Processing Record 49 of Set 6 | manta
# Processing Record 50 of Set 6 | ancud
# Processing Record 1 of Set 7 | phangnga
# Processing Record 2 of Set 7 | waipawa
# Processing Record 3 of Set 7 | coihaique
# Processing Record 4 of Set 7 | saldanha
# Processing Record 5 of Set 7 | baykit
# Processing Record 6 of Set 7 | barra do garcas
# Processing Record 7 of Set 7 | starosubkhangulovo
# Processing Record 8 of Set 7 | krasnoselkup
# Processing Record 9 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 10 of Set 7 | leshukonskoye
# Processing Record 11 of Set 7 | peterhead
# Processing Record 12 of Set 7 | berlevag
# Processing Record 13 of Set 7 | sarangani
# Processing Record 14 of Set 7 | buin
# Processing Record 15 of Set 7 | tibacuy
# Processing Record 16 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 17 of Set 7 | russell
# Processing Record 18 of Set 7 | balkanabat
# Processing Record 19 of Set 7 | key biscayne
# Processing Record 20 of Set 7 | saint-philippe
# Processing Record 21 of Set 7 | gazanjyk
# Processing Record 22 of Set 7 | angren
# Processing Record 23 of Set 7 | shubarshi
# Processing Record 24 of Set 7 | coquimbo
# Processing Record 25 of Set 7 | olafsvik
# Processing Record 26 of Set 7 | dabakala
# Processing Record 27 of Set 7 | henties bay
# Processing Record 28 of Set 7 | esperance
# Processing Record 29 of Set 7 | poronaysk
# Processing Record 30 of Set 7 | grand gaube
# Processing Record 31 of Set 7 | svetlogorsk
# Processing Record 32 of Set 7 | sistranda
# Processing Record 33 of Set 7 | progreso
# Processing Record 34 of Set 7 | westerly
# Processing Record 35 of Set 7 | wajima
# Processing Record 36 of Set 7 | zeya
# Processing Record 37 of Set 7 | arouca
# Processing Record 38 of Set 7 | shache
# Processing Record 39 of Set 7 | newburgh
# Processing Record 40 of Set 7 | auki
# Processing Record 41 of Set 7 | taranto
# Processing Record 42 of Set 7 | dvinskoy
# Processing Record 43 of Set 7 | fort frances
# Processing Record 44 of Set 7 | tulay
# Processing Record 45 of Set 7 | ugoofaaru
# Processing Record 46 of Set 7 | vestmannaeyjar
# Processing Record 47 of Set 7 | lagoa
# Processing Record 48 of Set 7 | north bend
# Processing Record 49 of Set 7 | manyoni
# Processing Record 50 of Set 7 | yantal
# Processing Record 1 of Set 8 | karpogory
# Processing Record 2 of Set 8 | the valley
# Processing Record 3 of Set 8 | soyo
# Processing Record 4 of Set 8 | sechura
# Processing Record 5 of Set 8 | uyuni
# Processing Record 6 of Set 8 | adre
# Processing Record 7 of Set 8 | marsh harbour
# Processing Record 8 of Set 8 | teguldet
# Processing Record 9 of Set 8 | beruni
# City not found. Skipping...
# Processing Record 10 of Set 8 | shumskiy
# Processing Record 11 of Set 8 | gambela
# Processing Record 12 of Set 8 | kieta
# Processing Record 13 of Set 8 | thompson
# Processing Record 14 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 15 of Set 8 | baoding
# Processing Record 16 of Set 8 | puerto escondido
# Processing Record 17 of Set 8 | ambrolauri
# Processing Record 18 of Set 8 | union hidalgo
# Processing Record 19 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 20 of Set 8 | ixtapa
# Processing Record 21 of Set 8 | kumluca
# Processing Record 22 of Set 8 | port hedland
# Processing Record 23 of Set 8 | murgab
# Processing Record 24 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 25 of Set 8 | leh
# Processing Record 26 of Set 8 | molteno
# Processing Record 27 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 28 of Set 8 | aykhal
# Processing Record 29 of Set 8 | tessalit
# Processing Record 30 of Set 8 | le port
# Processing Record 31 of Set 8 | port hardy
# Processing Record 32 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 8 | quang ngai
# Processing Record 34 of Set 8 | rexburg
# Processing Record 35 of Set 8 | pergamino
# Processing Record 36 of Set 8 | juneau
# Processing Record 37 of Set 8 | kabalo
# Processing Record 38 of Set 8 | sinnamary
# Processing Record 39 of Set 8 | caxito
# Processing Record 40 of Set 8 | nara
# Processing Record 41 of Set 8 | vangaindrano
# Processing Record 42 of Set 8 | waingapu
# Processing Record 43 of Set 8 | mandalgovi
# Processing Record 44 of Set 8 | mutoko
# Processing Record 45 of Set 8 | ust-nera
# Processing Record 46 of Set 8 | sept-iles
# Processing Record 47 of Set 8 | lubsko
# Processing Record 48 of Set 8 | aberystwyth
# Processing Record 49 of Set 8 | loa janan
# Processing Record 50 of Set 8 | mentok
# City not found. Skipping...
# Processing Record 1 of Set 9 | anadyr
# Processing Record 2 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 9 | ambilobe
# Processing Record 4 of Set 9 | ribas do rio pardo
# Processing Record 5 of Set 9 | vila velha
# Processing Record 6 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 9 | port pirie
# Processing Record 8 of Set 9 | channel-port aux basques
# Processing Record 9 of Set 9 | alofi
# Processing Record 10 of Set 9 | tual
# Processing Record 11 of Set 9 | ye
# City not found. Skipping...
# Processing Record 12 of Set 9 | bambous virieux
# Processing Record 13 of Set 9 | matagami
# Processing Record 14 of Set 9 | kalmar
# Processing Record 15 of Set 9 | oga
# Processing Record 16 of Set 9 | qaqortoq
# Processing Record 17 of Set 9 | khash
# Processing Record 18 of Set 9 | yenagoa
# Processing Record 19 of Set 9 | port hawkesbury
# Processing Record 20 of Set 9 | port shepstone
# Processing Record 21 of Set 9 | lagos
# Processing Record 22 of Set 9 | scarborough
# Processing Record 23 of Set 9 | bassila
# Processing Record 24 of Set 9 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 25 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 9 | tiarei
# Processing Record 27 of Set 9 | santa maria
# Processing Record 28 of Set 9 | pasir gudang
# Processing Record 29 of Set 9 | mildura
# Processing Record 30 of Set 9 | rosetown
# Processing Record 31 of Set 9 | imeni babushkina
# Processing Record 32 of Set 9 | crab hill
# City not found. Skipping...
# Processing Record 33 of Set 9 | litovko
# Processing Record 34 of Set 9 | camana
# Processing Record 35 of Set 9 | lidkoping
# Processing Record 36 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 37 of Set 9 | kloulklubed
# Processing Record 38 of Set 9 | malwan
# City not found. Skipping...
# Processing Record 39 of Set 9 | nelson bay
# Processing Record 40 of Set 9 | taywarah
# Processing Record 41 of Set 9 | mount pleasant
# Processing Record 42 of Set 9 | gualaco
# Processing Record 43 of Set 9 | matay
# Processing Record 44 of Set 9 | pitsunda
# Processing Record 45 of Set 9 | boguchany
# Processing Record 46 of Set 9 | yakeshi
# Processing Record 47 of Set 9 | rossland
# Processing Record 48 of Set 9 | mul
# Processing Record 49 of Set 9 | sulangan
# Processing Record 50 of Set 9 | ponta do sol
# Processing Record 1 of Set 10 | ville-marie
# Processing Record 2 of Set 10 | denpasar
# Processing Record 3 of Set 10 | corinto
# Processing Record 4 of Set 10 | sao filipe
# Processing Record 5 of Set 10 | cumaribo
# City not found. Skipping...
# Processing Record 6 of Set 10 | la ronge
# Processing Record 7 of Set 10 | gayny
# Processing Record 8 of Set 10 | boquira
# Processing Record 9 of Set 10 | shatrovo
# Processing Record 10 of Set 10 | safaga
# Processing Record 11 of Set 10 | eskasem
# City not found. Skipping...
# Processing Record 12 of Set 10 | mount gambier
# Processing Record 13 of Set 10 | chapais
# Processing Record 14 of Set 10 | anda
# Processing Record 15 of Set 10 | byron bay
# Processing Record 16 of Set 10 | nhulunbuy
# Processing Record 17 of Set 10 | praia da vitoria
# Processing Record 18 of Set 10 | carutapera
# Processing Record 19 of Set 10 | saint george
# Processing Record 20 of Set 10 | butterworth
# Processing Record 21 of Set 10 | lichuan
# Processing Record 22 of Set 10 | armacao dos buzios
# City not found. Skipping...
# Processing Record 23 of Set 10 | norman wells
# Processing Record 24 of Set 10 | labuhan
# Processing Record 25 of Set 10 | kelo
# Processing Record 26 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 27 of Set 10 | bilibino
# Processing Record 28 of Set 10 | tartagal
# Processing Record 29 of Set 10 | kozhevnikovo
# Processing Record 30 of Set 10 | denizli
# Processing Record 31 of Set 10 | noboribetsu
# Processing Record 32 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 33 of Set 10 | salme
# Processing Record 34 of Set 10 | isangel
# Processing Record 35 of Set 10 | ngunguru
# Processing Record 36 of Set 10 | la fria
# Processing Record 37 of Set 10 | vryburg
# Processing Record 38 of Set 10 | ranavav
# Processing Record 39 of Set 10 | guymon
# Processing Record 40 of Set 10 | pevek
# Processing Record 41 of Set 10 | nioro
# Processing Record 42 of Set 10 | konstantinovka
# Processing Record 43 of Set 10 | luanda
# Processing Record 44 of Set 10 | mrirt
# City not found. Skipping...
# Processing Record 45 of Set 10 | vila franca do campo
# Processing Record 46 of Set 10 | bonavista
# Processing Record 47 of Set 10 | narrabri
# Processing Record 48 of Set 10 | kaputa
# Processing Record 49 of Set 10 | sorland
# Processing Record 50 of Set 10 | santa
# Processing Record 1 of Set 11 | sakaraha
# Processing Record 2 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 3 of Set 11 | challapata
# Processing Record 4 of Set 11 | yerbogachen
# Processing Record 5 of Set 11 | monte carmelo
# Processing Record 6 of Set 11 | ahuimanu
# Processing Record 7 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 8 of Set 11 | deputatskiy
# Processing Record 9 of Set 11 | senj
# Processing Record 10 of Set 11 | boyolangu
# Processing Record 11 of Set 11 | cairns
# Processing Record 12 of Set 11 | whyalla
# Processing Record 13 of Set 11 | mehamn
# Processing Record 14 of Set 11 | goderich
# Processing Record 15 of Set 11 | marzuq
# Processing Record 16 of Set 11 | karratha
# Processing Record 17 of Set 11 | haflong
# Processing Record 18 of Set 11 | kemin
# Processing Record 19 of Set 11 | runcorn
# Processing Record 20 of Set 11 | amga
# Processing Record 21 of Set 11 | havelock
# Processing Record 22 of Set 11 | horodok
# Processing Record 23 of Set 11 | copiapo
# Processing Record 24 of Set 11 | prince rupert
# Processing Record 25 of Set 11 | ilulissat
# Processing Record 26 of Set 11 | marsa matruh
# Processing Record 27 of Set 11 | aitape
# Processing Record 28 of Set 11 | tauranga
# Processing Record 29 of Set 11 | sainte-thecle
# Processing Record 30 of Set 11 | vastervik
# City not found. Skipping...
# Processing Record 31 of Set 11 | caucaia
# Processing Record 32 of Set 11 | esqueda
# Processing Record 33 of Set 11 | aranos
# Processing Record 34 of Set 11 | stavern
# Processing Record 35 of Set 11 | san fernando
# Processing Record 36 of Set 11 | mount isa
# Processing Record 37 of Set 11 | matara
# Processing Record 38 of Set 11 | tiznit
# Processing Record 39 of Set 11 | mangalia
# Processing Record 40 of Set 11 | rauma
# Processing Record 41 of Set 11 | neosho
# Processing Record 42 of Set 11 | eureka
# Processing Record 43 of Set 11 | half moon bay
# Processing Record 44 of Set 11 | dali
# Processing Record 45 of Set 11 | brownsville
# Processing Record 46 of Set 11 | tuatapere
# Processing Record 47 of Set 11 | olinda
# Processing Record 48 of Set 11 | ziro
# Processing Record 49 of Set 11 | timra
# Processing Record 50 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 12 | hibbing
# Processing Record 2 of Set 12 | zaozhuang
# Processing Record 3 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 4 of Set 12 | nishihara
# Processing Record 5 of Set 12 | acari
# Processing Record 6 of Set 12 | geraldton
# Processing Record 7 of Set 12 | bairiki
# Processing Record 8 of Set 12 | sakakah
# Processing Record 9 of Set 12 | irbit
# Processing Record 10 of Set 12 | mwene-ditu
# Processing Record 11 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 12 | mangai
# Processing Record 13 of Set 12 | mahajanga
# Processing Record 14 of Set 12 | zion
# Processing Record 15 of Set 12 | brae
# Processing Record 16 of Set 12 | yongan
# Processing Record 17 of Set 12 | piacabucu
# Processing Record 18 of Set 12 | boli
# Processing Record 19 of Set 12 | jiancheng
# Processing Record 20 of Set 12 | cockburn town
# Processing Record 21 of Set 12 | campbell river
# Processing Record 22 of Set 12 | roald
# Processing Record 23 of Set 12 | shchelyayur
# City not found. Skipping...
# Processing Record 24 of Set 12 | kano
# Processing Record 25 of Set 12 | amahai
# Processing Record 26 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 27 of Set 12 | bubaque
# Processing Record 28 of Set 12 | cedral
# Processing Record 29 of Set 12 | pangody
# Processing Record 30 of Set 12 | dawson creek
# Processing Record 31 of Set 12 | emerald
# Processing Record 32 of Set 12 | savannah bight
# Processing Record 33 of Set 12 | konibodom
# Processing Record 34 of Set 12 | anchorage
# Processing Record 35 of Set 12 | yamada
# Processing Record 36 of Set 12 | laguna
# Processing Record 37 of Set 12 | biltine
# Processing Record 38 of Set 12 | buldana
# Processing Record 39 of Set 12 | belyy yar
# Processing Record 40 of Set 12 | batagay-alyta
# Processing Record 41 of Set 12 | golyshmanovo
# Processing Record 42 of Set 12 | sapa
# Processing Record 43 of Set 12 | palmer
# Processing Record 44 of Set 12 | imbituba
# Processing Record 45 of Set 12 | jacareacanga
# Processing Record 46 of Set 12 | pokaran
# Processing Record 47 of Set 12 | hopewell
# Processing Record 48 of Set 12 | gualeguay
# Processing Record 49 of Set 12 | torbat-e jam
# Processing Record 50 of Set 12 | ayame
# Processing Record 1 of Set 13 | salalah
# Processing Record 2 of Set 13 | harper
# Processing Record 3 of Set 13 | senanga
# Processing Record 4 of Set 13 | skagastrond
# City not found. Skipping...
# Processing Record 5 of Set 13 | san juan
# Processing Record 6 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 7 of Set 13 | manado
# Processing Record 8 of Set 13 | sydney
# Processing Record 9 of Set 13 | patacamaya
# Processing Record 10 of Set 13 | tonantins
# Processing Record 11 of Set 13 | hobyo
# Processing Record 12 of Set 13 | narsimhapur
# Processing Record 13 of Set 13 | benton
# Processing Record 14 of Set 13 | horta
# Processing Record 15 of Set 13 | tricase
# Processing Record 16 of Set 13 | awjilah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp          Current Description  \
# 0   Nikolskoye  59.7035   30.7861     75.09                broken clouds
# 1      Fortuna  40.5982 -124.1573     61.66                    clear sky
# 2  Yellowknife  62.4560 -114.3525     55.92  light intensity shower rain
# 3      Ushuaia -54.8000  -68.3000     44.26             scattered clouds
# 4     Cherskiy  68.7500  161.3000     53.65                broken clouds
# 5      College  64.8569 -147.8028     54.28                broken clouds
# 6        Bluff -46.6000  168.3333     41.13                    clear sky
# 7       Albany  42.6001  -73.9662     81.63                    clear sky
# 8       Castro -24.7911  -50.0119     78.46             scattered clouds
# 9     Banswara  23.5500   74.4500     76.77              overcast clouds
#
#    Humidity  Cloudiness  Wind Speed Country                 Date
# 0        55          68        3.87      RU  2022-08-28 17:42:11
# 1        94           0        5.75      US  2022-08-28 17:42:11
# 2        94         100       11.50      CA  2022-08-28 17:37:40
# 3        65          40        9.22      AR  2022-08-28 17:42:11
# 4        67          72        8.61      RU  2022-08-28 17:42:09
# 5        92          75        0.00      US  2022-08-28 17:38:55
# 6        87           6        5.50      NZ  2022-08-28 17:40:06
# 7        69           9        1.99      US  2022-08-28 17:37:32
# 8        35          42        3.94      BR  2022-08-28 17:42:12
# 9        80          98        1.97      IN  2022-08-28 17:42:13

# %%
# Reorder the columns in the order you want them to appear.
new_column_order = ["City", "Country", "Lat",
                    "Lng", "Max Temp", "Humidity", 
                    "Cloudiness", "Wind Speed", 
                    "Current Description"] 

# Assign a new or the same DataFrame the new column order.
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Nikolskoye      RU  59.7035   30.7861     75.09        55          68
# 1      Fortuna      US  40.5982 -124.1573     61.66        94           0
# 2  Yellowknife      CA  62.4560 -114.3525     55.92        94         100
# 3      Ushuaia      AR -54.8000  -68.3000     44.26        65          40
# 4     Cherskiy      RU  68.7500  161.3000     53.65        67          72
# 5      College      US  64.8569 -147.8028     54.28        92          75
# 6        Bluff      NZ -46.6000  168.3333     41.13        87           6
# 7       Albany      US  42.6001  -73.9662     81.63        69           9
# 8       Castro      BR -24.7911  -50.0119     78.46        35          42
# 9     Banswara      IN  23.5500   74.4500     76.77        80          98
#
#    Wind Speed          Current Description
# 0        3.87                broken clouds
# 1        5.75                    clear sky
# 2       11.50  light intensity shower rain
# 3        9.22             scattered clouds
# 4        8.61                broken clouds
# 5        0.00                broken clouds
# 6        5.50                    clear sky
# 7        1.99                    clear sky
# 8        3.94             scattered clouds
# 9        1.97              overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
